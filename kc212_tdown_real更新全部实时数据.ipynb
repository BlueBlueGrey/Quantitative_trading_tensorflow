# %%
# -*- coding: utf-8 -*-
'''
TopQuant-简称TQ极宽智能量化回溯分析系统，培训课件-配套教学python课件程序

Top极宽量化(原zw量化)，Python量化第一品牌 
by Top极宽·量化开源团队 2017.10.1 首发

网站： www.TopQuant.vip      www.ziwang.com
QQ群: Top极宽量化1群，124134140
      Top极宽量化2群，650924099
      Top极宽量化3群，450853713
  
'''

import os,arrow,shutil  
import numpy as np
import pandas as pd
import tushare as ts

#  TopQuant
import zsys 
import ztools as zt
import ztools_datadown as zddown

#----------

#1 下载股票实时数据文件
rss=zsys.rdatReal

# %%
print(rss)
rss='zDat/real/'
# Out:
# zDat/real/

# %%
zt.f_dirDel(rss) 
print('rs0:',rss)
#默认是下载5分钟分时数据
xtyp='5' 
print('xtyp:',xtyp)


#
#2 指数代码文件，下载所有指数实时数据
# 指数数据文件名是以“inx_”开头
finx='data/inx_code.csv'
print('\n#2,finx,',finx)
zddown.down_min_all(rss,finx,xtyp,fgIndex=True)



#3 股票代码文件，下载所有股票实时数据，可使用自定义股票池代码文件
#fstk='inx\\stk_code.csv'
fstk='data/stk_pool.csv'
print('\n#3,fstk,',fstk)
zddown.down_min_all(rss,fstk,xtyp,fgIndex=False)
# Out:
# rs0: zDat/real/
# xtyp: 5
#
# #2,finx, data/inx_code.csv
# data/inx_code.csv
#
#  0 / 24 code, 000001
#
#  zDat/real/inx_000001.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  1 / 24 code, 000002
#
#  zDat/real/inx_000002.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  2 / 24 code, 000003
#
#  zDat/real/inx_000003.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  3 / 24 code, 000008
#
#  zDat/real/inx_000008.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 24 code, 000009
#
#  zDat/real/inx_000009.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 24 code, 000010
#
#  zDat/real/inx_000010.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  6 / 24 code, 000011
#
#  zDat/real/inx_000011.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  7 / 24 code, 000012
#
#  zDat/real/inx_000012.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  8 / 24 code, 000016
#
#  zDat/real/inx_000016.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  9 / 24 code, 000017
#
#  zDat/real/inx_000017.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  10 / 24 code, 000300
#
#  zDat/real/inx_000300.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  11 / 24 code, 399001
#
#  zDat/real/inx_399001.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  12 / 24 code, 399002
#
#  zDat/real/inx_399002.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  13 / 24 code, 399003
#
#  zDat/real/inx_399003.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  14 / 24 code, 399004
#
#  zDat/real/inx_399004.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  15 / 24 code, 399005
#
#  zDat/real/inx_399005.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  16 / 24 code, 399006
#
#  zDat/real/inx_399006.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  17 / 24 code, 399100
#
#  zDat/real/inx_399100.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  18 / 24 code, 399101
#
#  zDat/real/inx_399101.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  19 / 24 code, 399106
#
#  zDat/real/inx_399106.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  20 / 24 code, 399107
#
#  zDat/real/inx_399107.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  21 / 24 code, 399108
#
#  zDat/real/inx_399108.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  22 / 24 code, 399333
#
#  zDat/real/inx_399333.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  23 / 24 code, 399606
#
#  zDat/real/inx_399606.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
# #3,fstk, data/stk_pool.csv
# data/stk_pool.csv
#
#  0 / 10 code, 600000
#
#  zDat/real/600000.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  1 / 10 code, 600016
#
#  zDat/real/600016.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  2 / 10 code, 600028
#
#  zDat/real/600028.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  3 / 10 code, 600029
#
#  zDat/real/600029.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 10 code, 600030
#
#  zDat/real/600030.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 10 code, 600036
#
#  zDat/real/600036.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  6 / 10 code, 600048
#
#  zDat/real/600048.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  7 / 10 code, 600050
#
#  zDat/real/600050.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  8 / 10 code, 600100
#
#  zDat/real/600100.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  9 / 10 code, 600104
#
#  zDat/real/600104.csv , 2020-10-21
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
