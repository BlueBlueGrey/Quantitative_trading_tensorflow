# %%
# -*- coding: utf-8 -*-
'''
TopQuant-简称TQ极宽智能量化回溯分析系统，培训课件-配套教学python课件程序

Top极宽量化(原zw量化)，Python量化第一品牌 
by Top极宽·量化开源团队 2017.10.1 首发

网站： www.TopQuant.vip      www.ziwang.com
QQ群: Top极宽量化1群，124134140
      Top极宽量化2群，650924099
      Top极宽量化3群，450853713
  
'''

import os
import numpy as np
import pandas as pd
import tushare as ts

#  TopQuant
import zsys 
import ztools_datadown as zddown

#----------

#下载股票日线数据文件，
#1
#rs0=zsys.rdatMin0+'M05/'
rs0=zsys.rdatMin0
print('rs0:',rs0)

#
xtyp='5'
xss=xtyp
if len(xtyp)==1:xss='0'+xss
rss=rs0+'M'+xss+'/'
print('rss#1:',rss)
#
rss='tmp/'
print('rss#2:',rss)
#
#2，设置股票代码文件 ，批量下载数据
#finx='inx\\stk_code.csv';
finx='data/stk_pool.csv';
zddown.down_stk_all(rss,finx,xtyp)
# Out:
# rs0: zDat/min/
# rss#1: zDat/min/M05/
# rss#2: tmp/
# data/stk_pool.csv
#
#  0 / 10 code, 600000
# ******
# tmp/ 600000 5
# ******
# 	 False tmp/600000.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  1 / 10 code, 600016
# ******
# tmp/ 600016 5
# ******
# 	 False tmp/600016.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  2 / 10 code, 600028
# ******
# tmp/ 600028 5
# ******
# 	 False tmp/600028.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  3 / 10 code, 600029
# ******
# tmp/ 600029 5
# ******
# 	 False tmp/600029.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 10 code, 600030
# ******
# tmp/ 600030 5
# ******
# 	 False tmp/600030.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 10 code, 600036
# ******
# tmp/ 600036 5
# ******
# 	 False tmp/600036.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  6 / 10 code, 600048
# ******
# tmp/ 600048 5
# ******
# 	 False tmp/600048.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  7 / 10 code, 600050
# ******
# tmp/ 600050 5
# ******
# 	 False tmp/600050.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  8 / 10 code, 600100
# ******
# tmp/ 600100 5
# ******
# 	 False tmp/600100.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  9 / 10 code, 600104
# ******
# tmp/ 600104 5
# ******
# 	 False tmp/600104.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
