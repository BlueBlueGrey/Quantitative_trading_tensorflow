# %%
# -*- coding: utf-8 -*-
'''
TopQuant-简称TQ极宽智能量化回溯分析系统，培训课件-配套教学python课件程序

Top极宽量化(原zw量化)，Python量化第一品牌 
by Top极宽·量化开源团队 2017.10.1 首发

网站： www.TopQuant.vip      www.ziwang.com
QQ群: Top极宽量化1群，124134140
      Top极宽量化2群，650924099
      Top极宽量化3群，450853713
  
'''

import os
import numpy as np
import pandas as pd
import tushare as ts

#  TopQuant
import zsys 
import ztools_datadown as zddown

#----------
#1 数据文件总目录
rs0=zsys.rdatCN0
print('\n#1 rs0:',rs0)

#2 指数索引文件,数据文件保存目录
finx,rss='inx/inx_code.csv',rs0+'xday/'
print('\n#2,finx,',finx)
#下载大盘指数文件，
zddown.down_stk_inx(rss,finx);


#------------------------------
#3.1,下载股票分时数据文件
rsm=zsys.rdatMin0
print('\n#3,rsm:',rsm)
#
xtyp='5'
xss=xtyp
if len(xtyp)==1:xss='0'+xss
rss=rsm+'M'+xss+'/'
print('rss:',rss)
#
#finx='inx\\stk_code.csv';
finx='data/bt-stk06.csv';
#codLst=['000001','002046','600663','000792','600029','000800']
print('\n#3.1 下载股票分时数据，finx,',finx)
zddown.down_stk_all(rss,finx,xtyp)


#3.2，下载指数分时数据文件，
print('\n#3.2 下载指数分时数据，finx,',finx)
#rs0=zsys.rdatMin0+'M05/'
rss=rs0+'XM'+xss+'/'
finx='inx/inx_code.csv';
zddown.down_stk_all(rss,finx,xtyp,True)

#--------------
 
#4下载股票日线数据文件，
rss=rs0+'day/' 
print('\n#4,rss:',rss)

#
#finx='inx\\stk_code.csv';
finx='data/bt-stk06.csv';
zddown.down_stk_all(rss,finx,'D')
# Out:
# #1 rs0: zDat/cn/
#
# #2,finx, inx/inx_code.csv
# inx/inx_code.csv
#
#  1 / 24 code, 000001 1994-01-01
#
#  True zDat/cn/xday/000001.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  2 / 24 code, 000002 1994-01-01
#
#  True zDat/cn/xday/000002.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  3 / 24 code, 000003 1994-01-01
#
#  True zDat/cn/xday/000003.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 24 code, 000008 1994-01-01
#
#  True zDat/cn/xday/000008.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 24 code, 000009 2011-01-01
#
#  True zDat/cn/xday/000009.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  6 / 24 code, 000010 2000-01-01
#
#  True zDat/cn/xday/000010.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  7 / 24 code, 000011 2001-01-01
#
#  True zDat/cn/xday/000011.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  8 / 24 code, 000012 2003-01-01
#
#  True zDat/cn/xday/000012.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  9 / 24 code, 000016 2004-01-01
#
#  True zDat/cn/xday/000016.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  10 / 24 code, 000017 2006-01-01
#
#  True zDat/cn/xday/000017.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  11 / 24 code, 000300 2005-01-01
#
#  True zDat/cn/xday/000300.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  12 / 24 code, 399001 1994-01-01
#
#  True zDat/cn/xday/399001.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  13 / 24 code, 399002 1994-01-01
#
#  True zDat/cn/xday/399002.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  14 / 24 code, 399003 1994-01-01
#
#  True zDat/cn/xday/399003.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  15 / 24 code, 399004 2003-01-01
#
#  True zDat/cn/xday/399004.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  16 / 24 code, 399005 2009-01-01
#
#  True zDat/cn/xday/399005.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  17 / 24 code, 399006 2011-01-01
#
#  True zDat/cn/xday/399006.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  18 / 24 code, 399100 2006-01-01
#
#  True zDat/cn/xday/399100.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  19 / 24 code, 399101 2006-01-01
#
#  True zDat/cn/xday/399101.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  20 / 24 code, 399106 2000-01-01
#
#  True zDat/cn/xday/399106.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  21 / 24 code, 399107 2000-01-01
#
#  True zDat/cn/xday/399107.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  22 / 24 code, 399108 2000-01-01
#
#  True zDat/cn/xday/399108.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  23 / 24 code, 399333 2007-01-01
#
#  True zDat/cn/xday/399333.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  24 / 24 code, 399606 2011-01-01
#
#  True zDat/cn/xday/399606.csv , 2020-11-25
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
# #3,rsm: zDat/min/
# rss: zDat/min/M05/
#
# #3.1 下载股票分时数据，finx, data/bt-stk06.csv
# data/bt-stk06.csv
#
#  0 / 6 code, 000001
# ******
# zDat/min/M05/ 000001 5
# ******
# 	 False zDat/min/M05/000001.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  1 / 6 code, 002046
# ******
# zDat/min/M05/ 002046 5
# ******
# 	 False zDat/min/M05/002046.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  2 / 6 code, 600663
# ******
# zDat/min/M05/ 600663 5
# ******
# 	 False zDat/min/M05/600663.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  3 / 6 code, 000792
# ******
# zDat/min/M05/ 000792 5
# ******
# 	 False zDat/min/M05/000792.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 6 code, 600029
# ******
# zDat/min/M05/ 600029 5
# ******
# 	 False zDat/min/M05/600029.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 6 code, 000800
# ******
# zDat/min/M05/ 000800 5
# ******
# 	 False zDat/min/M05/000800.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
# #3.2 下载指数分时数据，finx, data/bt-stk06.csv
# inx/inx_code.csv
#
#  0 / 24 code, 000001
# ******
# zDat/cn/XM05/ 000001 5
# ******
# 	 False zDat/cn/XM05/000001.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  1 / 24 code, 000002
# ******
# zDat/cn/XM05/ 000002 5
# ******
# 	 False zDat/cn/XM05/000002.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  2 / 24 code, 000003
# ******
# zDat/cn/XM05/ 000003 5
# ******
# 	 False zDat/cn/XM05/000003.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  3 / 24 code, 000008
# ******
# zDat/cn/XM05/ 000008 5
# ******
# 	 False zDat/cn/XM05/000008.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 24 code, 000009
# ******
# zDat/cn/XM05/ 000009 5
# ******
# 	 False zDat/cn/XM05/000009.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 24 code, 000010
# ******
# zDat/cn/XM05/ 000010 5
# ******
# 	 False zDat/cn/XM05/000010.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  6 / 24 code, 000011
# ******
# zDat/cn/XM05/ 000011 5
# ******
# 	 False zDat/cn/XM05/000011.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  7 / 24 code, 000012
# ******
# zDat/cn/XM05/ 000012 5
# ******
# 	 False zDat/cn/XM05/000012.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  8 / 24 code, 000016
# ******
# zDat/cn/XM05/ 000016 5
# ******
# 	 False zDat/cn/XM05/000016.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  9 / 24 code, 000017
# ******
# zDat/cn/XM05/ 000017 5
# ******
# 	 False zDat/cn/XM05/000017.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  10 / 24 code, 000300
# ******
# zDat/cn/XM05/ 000300 5
# ******
# 	 False zDat/cn/XM05/000300.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  11 / 24 code, 399001
# ******
# zDat/cn/XM05/ 399001 5
# ******
# 	 False zDat/cn/XM05/399001.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  12 / 24 code, 399002
# ******
# zDat/cn/XM05/ 399002 5
# ******
# 	 False zDat/cn/XM05/399002.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  13 / 24 code, 399003
# ******
# zDat/cn/XM05/ 399003 5
# ******
# 	 False zDat/cn/XM05/399003.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  14 / 24 code, 399004
# ******
# zDat/cn/XM05/ 399004 5
# ******
# 	 False zDat/cn/XM05/399004.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  15 / 24 code, 399005
# ******
# zDat/cn/XM05/ 399005 5
# ******
# 	 False zDat/cn/XM05/399005.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  16 / 24 code, 399006
# ******
# zDat/cn/XM05/ 399006 5
# ******
# 	 False zDat/cn/XM05/399006.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  17 / 24 code, 399100
# ******
# zDat/cn/XM05/ 399100 5
# ******
# 	 False zDat/cn/XM05/399100.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  18 / 24 code, 399101
# ******
# zDat/cn/XM05/ 399101 5
# ******
# 	 False zDat/cn/XM05/399101.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  19 / 24 code, 399106
# ******
# zDat/cn/XM05/ 399106 5
# ******
# 	 False zDat/cn/XM05/399106.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  20 / 24 code, 399107
# ******
# zDat/cn/XM05/ 399107 5
# ******
# 	 False zDat/cn/XM05/399107.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  21 / 24 code, 399108
# ******
# zDat/cn/XM05/ 399108 5
# ******
# 	 False zDat/cn/XM05/399108.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  22 / 24 code, 399333
# ******
# zDat/cn/XM05/ 399333 5
# ******
# 	 False zDat/cn/XM05/399333.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  23 / 24 code, 399606
# ******
# zDat/cn/XM05/ 399606 5
# ******
# 	 False zDat/cn/XM05/399606.csv , 1994-01-01
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
# #4,rss: zDat/cn/day/
# data/bt-stk06.csv
#
#  0 / 6 code, 000001
# ******
# zDat/cn/day/ 000001 D
# ******
# 	 True zDat/cn/day/000001.csv , 2020-02-19
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  1 / 6 code, 002046
# ******
# zDat/cn/day/ 002046 D
# ******
# 	 True zDat/cn/day/002046.csv , 2020-02-19
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#  2 / 6 code, 600663
# ******
# zDat/cn/day/ 600663 D
# ******
# 	 True zDat/cn/day/600663.csv , 2020-02-19
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
# Remote end closed connection without response
#
#  3 / 6 code, 000792
# ******
# zDat/cn/day/ 000792 D
# ******
# 	 True zDat/cn/day/000792.csv , 2020-02-19
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  4 / 6 code, 600029
# ******
# zDat/cn/day/ 600029 D
# ******
# 	 True zDat/cn/day/600029.csv , 2020-10-16
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#
#  5 / 6 code, 000800
# ******
# zDat/cn/day/ 000800 D
# ******
# 	 True zDat/cn/day/000800.csv , 2020-02-19
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2

# %%
pip list
# Out:
# Package                                           Version
# ------------------------------------------------- ----------
# alabaster                                         0.7.12
# appdirs                                           1.4.4
# applaunchservices                                 0.2.1
# appnope                                           0.1.0
# argon2-cffi                                       20.1.0
# arrow                                             0.10.0
# astroid                                           2.4.2
# async-generator                                   1.10
# atomicwrites                                      1.4.0
# attrs                                             20.2.0
# autopep8                                          1.5.4
# Babel                                             2.9.0
# backcall                                          0.2.0
# backtrader                                        1.9.76.123
# beautifulsoup4                                    4.9.1
# black                                             20.8b1
# bleach                                            1.5.0
# bs4                                               0.0.1
# cached-property                                   1.5.1
# certifi                                           2020.6.20
# cffi                                              1.14.2
# chardet                                           3.0.4
# click                                             7.1.2
# cloudpickle                                       1.6.0
# cycler                                            0.10.0
# dataclasses                                       0.8
# decorator                                         4.4.2
# defusedxml                                        0.6.0
# diff-match-patch                                  20200713
# docutils                                          0.16
# empyrical                                         0.5.5
# entrypoints                                       0.3
# ffn                                               0.3.4
# flake8                                            3.8.4
# future                                            0.18.2
# graphviz                                          0.14.2
# h5py                                              2.10.0
# helpdev                                           0.7.1
# html5lib                                          0.9999999
# idna                                              2.10
# imageio                                           2.9.0
# imagesize                                         1.2.0
# importlib-metadata                                1.7.0
# inflection                                        0.5.1
# intervaltree                                      3.1.0
# ipykernel                                         5.3.4
# ipython                                           7.16.1
# ipython-genutils                                  0.2.0
# ipywidgets                                        7.5.1
# isort                                             5.6.4
# jedi                                              0.17.2
# Jinja2                                            2.11.2
# joblib                                            0.17.0
# jsonschema                                        3.2.0
# jupyter                                           1.0.0
# jupyter-client                                    6.1.7
# jupyter-console                                   6.2.0
# jupyter-core                                      4.6.3
# jupyterlab-pygments                               0.1.1
# Keras                                             2.0.7
# keyring                                           21.5.0
# kiwisolver                                        1.3.1
# lazy-object-proxy                                 1.4.3
# lxml                                              4.5.2
# Markdown                                          3.2.2
# MarkupSafe                                        1.1.1
# matplotlib                                        2.1.0
# mccabe                                            0.6.1
# metrics                                           0.3.3
# mistune                                           0.8.4
# more-itertools                                    8.6.0
# mypy-extensions                                   0.4.3
# nbclient                                          0.5.0
# nbconvert                                         6.0.4
# nbformat                                          5.0.7
# nest-asyncio                                      1.4.0
# networkx                                          2.5
# nltk                                              3.2.4
# notebook                                          6.1.4
# numexpr                                           2.7.1
# numpy                                             1.16.0
# numpydoc                                          1.1.0
# packaging                                         20.4
# pandas                                            0.21.0
# pandas-datareader                                 0.9.0
# pandocfilters                                     1.4.2
# parso                                             0.7.0
# pathlib2                                          2.3.5
# pathspec                                          0.8.1
# pathtools                                         0.1.2
# pexpect                                           4.8.0
# pickleshare                                       0.7.5
# Pillow                                            7.2.0
# pip                                               20.2.4
# plotly                                            2.0.15
# pluggy                                            0.13.1
# prometheus-client                                 0.8.0
# prompt-toolkit                                    3.0.7
# protobuf                                          3.13.0
# psutil                                            5.7.2
# ptyprocess                                        0.6.0
# py-cpuinfo                                        7.0.0
# pycodestyle                                       2.6.0
# pycparser                                         2.20
# pydocstyle                                        5.1.1
# pydot                                             1.4.1
# pyflakes                                          2.2.0
# pyfolio                                           0.9.2
# Pygments                                          2.7.1
# pylint                                            2.6.0
# pyls-black                                        0.4.6
# pyls-spyder                                       0.1.1
# pyobjc                                            6.2.2
# pyobjc-core                                       6.2.2
# pyobjc-framework-Accounts                         6.2.2
# pyobjc-framework-AddressBook                      6.2.2
# pyobjc-framework-AdSupport                        6.2.2
# pyobjc-framework-AppleScriptKit                   6.2.2
# pyobjc-framework-AppleScriptObjC                  6.2.2
# pyobjc-framework-ApplicationServices              6.2.2
# pyobjc-framework-AuthenticationServices           6.2.2
# pyobjc-framework-AutomaticAssessmentConfiguration 6.2.2
# pyobjc-framework-Automator                        6.2.2
# pyobjc-framework-AVFoundation                     6.2.2
# pyobjc-framework-AVKit                            6.2.2
# pyobjc-framework-BusinessChat                     6.2.2
# pyobjc-framework-CalendarStore                    6.2.2
# pyobjc-framework-CFNetwork                        6.2.2
# pyobjc-framework-CloudKit                         6.2.2
# pyobjc-framework-Cocoa                            6.2.2
# pyobjc-framework-Collaboration                    6.2.2
# pyobjc-framework-ColorSync                        6.2.2
# pyobjc-framework-Contacts                         6.2.2
# pyobjc-framework-ContactsUI                       6.2.2
# pyobjc-framework-CoreAudio                        6.2.2
# pyobjc-framework-CoreAudioKit                     6.2.2
# pyobjc-framework-CoreBluetooth                    6.2.2
# pyobjc-framework-CoreData                         6.2.2
# pyobjc-framework-CoreHaptics                      6.2.2
# pyobjc-framework-CoreLocation                     6.2.2
# pyobjc-framework-CoreMedia                        6.2.2
# pyobjc-framework-CoreMediaIO                      6.2.2
# pyobjc-framework-CoreML                           6.2.2
# pyobjc-framework-CoreMotion                       6.2.2
# pyobjc-framework-CoreServices                     6.2.2
# pyobjc-framework-CoreSpotlight                    6.2.2
# pyobjc-framework-CoreText                         6.2.2
# pyobjc-framework-CoreWLAN                         6.2.2
# pyobjc-framework-CryptoTokenKit                   6.2.2
# pyobjc-framework-DeviceCheck                      6.2.2
# pyobjc-framework-DictionaryServices               6.2.2
# pyobjc-framework-DiscRecording                    6.2.2
# pyobjc-framework-DiscRecordingUI                  6.2.2
# pyobjc-framework-DiskArbitration                  6.2.2
# pyobjc-framework-DVDPlayback                      6.2.2
# pyobjc-framework-EventKit                         6.2.2
# pyobjc-framework-ExceptionHandling                6.2.2
# pyobjc-framework-ExecutionPolicy                  6.2.2
# pyobjc-framework-ExternalAccessory                6.2.2
# pyobjc-framework-FileProvider                     6.2.2
# pyobjc-framework-FileProviderUI                   6.2.2
# pyobjc-framework-FinderSync                       6.2.2
# pyobjc-framework-FSEvents                         6.2.2
# pyobjc-framework-GameCenter                       6.2.2
# pyobjc-framework-GameController                   6.2.2
# pyobjc-framework-GameKit                          6.2.2
# pyobjc-framework-GameplayKit                      6.2.2
# pyobjc-framework-ImageCaptureCore                 6.2.2
# pyobjc-framework-IMServicePlugIn                  6.2.2
# pyobjc-framework-InputMethodKit                   6.2.2
# pyobjc-framework-InstallerPlugins                 6.2.2
# pyobjc-framework-InstantMessage                   6.2.2
# pyobjc-framework-Intents                          6.2.2
# pyobjc-framework-IOSurface                        6.2.2
# pyobjc-framework-iTunesLibrary                    6.2.2
# pyobjc-framework-LatentSemanticMapping            6.2.2
# pyobjc-framework-LaunchServices                   6.2.2
# pyobjc-framework-libdispatch                      6.2.2
# pyobjc-framework-LinkPresentation                 6.2.2
# pyobjc-framework-LocalAuthentication              6.2.2
# pyobjc-framework-MapKit                           6.2.2
# pyobjc-framework-MediaAccessibility               6.2.2
# pyobjc-framework-MediaLibrary                     6.2.2
# pyobjc-framework-MediaPlayer                      6.2.2
# pyobjc-framework-MediaToolbox                     6.2.2
# pyobjc-framework-Metal                            6.2.2
# pyobjc-framework-MetalKit                         6.2.2
# pyobjc-framework-ModelIO                          6.2.2
# pyobjc-framework-MultipeerConnectivity            6.2.2
# pyobjc-framework-NaturalLanguage                  6.2.2
# pyobjc-framework-NetFS                            6.2.2
# pyobjc-framework-Network                          6.2.2
# pyobjc-framework-NetworkExtension                 6.2.2
# pyobjc-framework-NotificationCenter               6.2.2
# pyobjc-framework-OpenDirectory                    6.2.2
# pyobjc-framework-OSAKit                           6.2.2
# pyobjc-framework-OSLog                            6.2.2
# pyobjc-framework-PencilKit                        6.2.2
# pyobjc-framework-Photos                           6.2.2
# pyobjc-framework-PhotosUI                         6.2.2
# pyobjc-framework-PreferencePanes                  6.2.2
# pyobjc-framework-PushKit                          6.2.2
# pyobjc-framework-Quartz                           6.2.2
# pyobjc-framework-QuickLookThumbnailing            6.2.2
# pyobjc-framework-SafariServices                   6.2.2
# pyobjc-framework-SceneKit                         6.2.2
# pyobjc-framework-ScreenSaver                      6.2.2
# pyobjc-framework-ScriptingBridge                  6.2.2
# pyobjc-framework-SearchKit                        6.2.2
# pyobjc-framework-Security                         6.2.2
# pyobjc-framework-SecurityFoundation               6.2.2
# pyobjc-framework-SecurityInterface                6.2.2
# pyobjc-framework-ServiceManagement                6.2.2
# pyobjc-framework-Social                           6.2.2
# pyobjc-framework-SoundAnalysis                    6.2.2
# pyobjc-framework-Speech                           6.2.2
# pyobjc-framework-SpriteKit                        6.2.2
# pyobjc-framework-StoreKit                         6.2.2
# pyobjc-framework-SyncServices                     6.2.2
# pyobjc-framework-SystemConfiguration              6.2.2
# pyobjc-framework-SystemExtensions                 6.2.2
# pyobjc-framework-UserNotifications                6.2.2
# pyobjc-framework-VideoSubscriberAccount           6.2.2
# pyobjc-framework-VideoToolbox                     6.2.2
# pyobjc-framework-Vision                           6.2.2
# pyobjc-framework-WebKit                           6.2.2
# pyparsing                                         2.4.7
# pypinyin                                          0.39.0
# PyQt5                                             5.12.3
# PyQt5-sip                                         12.8.1
# PyQtWebEngine                                     5.12.1
# pyrsistent                                        0.17.3
# python-dateutil                                   2.8.1
# python-jsonrpc-server                             0.4.0
# python-language-server                            0.36.1
# pytz                                              2020.1
# PyWavelets                                        1.1.1
# PyYAML                                            5.3.1
# pyzmq                                             19.0.2
# QDarkStyle                                        2.8.1
# QtAwesome                                         1.0.1
# qtconsole                                         4.7.7
# QtPy                                              1.9.0
# Quandl                                            3.5.3
# regex                                             2020.11.13
# requests                                          2.24.0
# robobrowser                                       0.5.3
# rope                                              0.18.0
# scikit-image                                      0.17.2
# scikit-learn                                      0.23.2
# scipy                                             1.5.2
# seaborn                                           0.11.0
# Send2Trash                                        1.5.0
# setuptools                                        50.3.0
# simplejson                                        3.17.2
# six                                               1.15.0
# sklearn                                           0.0
# snowballstemmer                                   2.0.0
# sortedcontainers                                  2.3.0
# soupsieve                                         2.0.1
# Sphinx                                            3.3.1
# sphinxcontrib-applehelp                           1.0.2
# sphinxcontrib-devhelp                             1.0.2
# sphinxcontrib-htmlhelp                            1.0.3
# sphinxcontrib-jsmath                              1.0.1
# sphinxcontrib-qthelp                              1.0.3
# sphinxcontrib-serializinghtml                     1.1.4
# spyder                                            4.2.0
# spyder-kernels                                    1.10.0
# tabulate                                          0.8.7
# tensorflow                                        1.3.0
# tensorflow-tensorboard                            0.1.8
# tensorlayer                                       1.6.1
# terminado                                         0.8.3
# testpath                                          0.4.4
# tflearn                                           0.3.2
# Theano                                            1.0.5
# threadpoolctl                                     2.1.0
# three-merge                                       0.1.1
# tifffile                                          2020.9.3
# toml                                              0.10.2
# tornado                                           6.0.4
# traitlets                                         4.3.3
# tushare                                           1.2.60
# typed-ast                                         1.4.1
# typing-extensions                                 3.7.4.3
# ujson                                             4.0.1
# urllib3                                           1.25.10
# watchdog                                          0.10.4
# wcwidth                                           0.2.5
# websocket-client                                  0.57.0
# Werkzeug                                          0.16.0
# wheel                                             0.35.1
# widgetsnbextension                                3.5.1
# wrapt                                             1.12.1
# wurlitzer                                         2.0.1
# yapf                                              0.30.0
# zipp                                              3.1.0
# Note: you may need to restart the kernel to use updated packages.
