# %%
# -*- coding: utf-8 -*-
'''
TopQuant-简称TQ极宽智能量化回溯分析系统，培训课件-配套教学python课件程序

Top极宽量化(原zw量化)，Python量化第一品牌 
by Top极宽·量化开源团队 2017.10.1 首发

网站： www.TopQuant.vip      www.ziwang.com
QQ群: Top极宽量化1群，124134140
      Top极宽量化2群，650924099
      Top极宽量化3群，450853713
  
'''

import os,sys,math,arrow,ffn
import pypinyin 
import numpy as np
import pandas as pd
import pandas_datareader as pdr 
import matplotlib.pyplot as plt
#
'''
from sklearn.datasets import samples_generator
#
import keras
from keras import initializers
from keras import models,layers
from keras.models import Sequential,load_model
from keras.layers import Dense, Input, Dropout, Embedding, LSTM, Bidirectional,Activation,SimpleRNN
from keras.optimizers import RMSprop, SGD  
from keras.applications.resnet50 import preprocess_input, decode_predictions
#
import tensorlayer as tl
import tensorflow as tf
'''
#
import zsys 
import ztools as zt
import ztools_str as zstr
import ztools_data as zdat
import ztools_draw as zdr
import ztools_tq as ztq
import zpd_talib as zta
#

#-------------------

#-------------------


#1
fss='inx/inx_code.csv'
df=pd.read_csv(fss,dtype={'code' : str},encoding='GBK')
print('\n#1,fss,',fss)
print('\ndf.tail')
print(df.tail())

#2 编辑转换数据 
print('\n#2,data edit')
df2=pd.DataFrame()
# 使用 iterrows 更快  中文变成英文方便分析
for i, row in df.iterrows():
    css=row['name']
    ess=pypinyin.slug(css, style=pypinyin.FIRST_LETTER, separator='')
    row['ename']=ess.upper()+'_'+row['code']
    row['id']=int(i)
    df2=df2.append(row)
    
#3
# 强制转化成int 否则为浮点数
df2['id']=df2['id'].astype(int)
fss='tmp/xinx_name.csv'
print('\n#3,fss,',fss)
df2.to_csv(fss,index=False,encoding='GBK')    
#
print('\ndf2.tail')
print(df2.tail())
# Out:
# Using TensorFlow backend.
# /Users/bluegrey/py3env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:458: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /Users/bluegrey/py3env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:459: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /Users/bluegrey/py3env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:460: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /Users/bluegrey/py3env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:461: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /Users/bluegrey/py3env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:462: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# /Users/bluegrey/py3env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:465: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# hdf5 is not supported on this machine (please install/reinstall h5py for optimal experience)
#
# #1,fss, inx/inx_code.csv
#
# df.tail
#       code  name        tim0
# 19  399106  深证综指  2000-01-01
# 20  399107  深证A指  2000-01-01
# 21  399108  深证B指  2000-01-01
# 22  399333  中小板R  2007-01-01
# 23  399606  创业板R  2011-01-01
#
# #2,data edit
#
# #3,fss, tmp/xinx_name.csv
#
# df2.tail
#       code        ename  id  name        tim0
# 19  399106  SZZZ_399106  19  深证综指  2000-01-01
# 20  399107  SZAZ_399107  20  深证A指  2000-01-01
# 21  399108  SZBZ_399108  21  深证B指  2000-01-01
# 22  399333  ZXBR_399333  22  中小板R  2007-01-01
# 23  399606  CYBR_399606  23  创业板R  2011-01-01

# %%
pip install ffn
# Out:
# Collecting ffn
#   Downloading ffn-0.3.4.tar.gz (21 kB)
# Requirement already satisfied: decorator>=4 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from ffn) (4.4.2)
# Requirement already satisfied: numpy>=1.5 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from ffn) (1.19.2)
# Requirement already satisfied: pandas>=0.19 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from ffn) (0.20.3)
# Collecting pandas-datareader>=0.2
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 354 kB/s eta 0:00:01
# Collecting tabulate>=0.7.5
#   Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Requirement already satisfied: matplotlib>=1 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from ffn) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.15 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from ffn) (0.23.2)
# Requirement already satisfied: scipy>=0.15 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from ffn) (1.5.2)
# Collecting future>=0.15
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 922 kB/s eta 0:00:01
# Requirement already satisfied: pytz>=2011k in /Users/bluegrey/py3env/lib/python3.6/site-packages (from pandas>=0.19->ffn) (2020.1)
# Requirement already satisfied: python-dateutil>=2 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from pandas>=0.19->ffn) (2.8.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from pandas-datareader>=0.2->ffn) (2.24.0)
# Requirement already satisfied: lxml in /Users/bluegrey/py3env/lib/python3.6/site-packages (from pandas-datareader>=0.2->ffn) (4.5.2)
# Requirement already satisfied: six>=1.10 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from matplotlib>=1->ffn) (1.15.0)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from matplotlib>=1->ffn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from matplotlib>=1->ffn) (0.10.0)
# Requirement already satisfied: joblib>=0.11 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from scikit-learn>=0.15->ffn) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from scikit-learn>=0.15->ffn) (2.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bluegrey/py3env/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2020.6.20)
# Building wheels for collected packages: ffn, future
#   Building wheel for ffn (setup.py) ... done
#   Created wheel for ffn: filename=ffn-0.3.4-py3-none-any.whl size=22811 sha256=660ca0c8f105f779fae45a0712f326b2000a798482413066b4005ee74c7d57ae
#   Stored in directory: /Users/bluegrey/Library/Caches/pip/wheels/2b/4f/6d/9713f7aa208c38e44a0abbe064a3a27130a349476c20dc97bd
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=cac832c6686290a43d5d7dc4e4aee1b122e3009d0130efbddba2a59344c661aa
#   Stored in directory: /Users/bluegrey/Library/Caches/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
# Successfully built ffn future
# Installing collected packages: pandas-datareader, tabulate, future, ffn
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# pandas-datareader 0.9.0 requires pandas>=0.23, but you'll have pandas 0.20.3 which is incompatible.
# Successfully installed ffn-0.3.4 future-0.18.2 pandas-datareader-0.9.0 tabulate-0.8.7
# Note: you may need to restart the kernel to use updated packages.
